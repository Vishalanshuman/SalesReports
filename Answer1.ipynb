# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
marital_status=df['Marital_Status'].unique()
marital_status
# Out:
# array([0, 1], dtype=int64)

# %%
# unique Maried Status
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Age',bins=20,kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['Product_Category_1'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 173638

# %%
df['Product_Category_3'].isnull().sum()
# Out:
# 383247

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(0)
df['Product_Category_3']=df['Product_Category_3'].fillna(0)
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["Purchase"],bins=20,kde=True)
plt.title("Purchase Items Distribution")
plt.xlabel('Purchase Items')
plt.ylabel('Frequency')
plt.show()

# %%
# Getting Outliers
plt.figure(figsize=(10,6))
sns.boxplot(df['Purchase'])
plt.xlabel("Purchase Itmes")
plt.title("BoxPlot of Purchase")
plt.show()

# %%
# Removing Outliers
df=df[df['Purchase']<20000]

plt.figure(figsize=(10,6))
sns.boxplot(df['Purchase'])
plt.title('Box Plot of Purchase After Removing Outliers')
plt.xlabel("Purchase Items")
plt.show()

# %%
# Analysis By Gender
gender_analysis=df.groupby('Gender')['Purchase'].mean()
gender_analysis
# Out:
# Gender
# F    8472.055690
# M    9153.015436
# Name: Purchase, dtype: float64

# %%
# Analysis By Marital Status
marital_status_analysis=df.groupby('Marital_Status')['Purchase'].mean()
marital_status_analysis
# Out:
# Marital_Status
# 0    8989.944095
# 1    8976.637679
# Name: Purchase, dtype: float64

# %%
#analysis By Occupation
occupation_analysis=df.groupby('Occupation')['Purchase'].mean()
occupation_analysis
# Out:
# Occupation
# 0     8856.870664
# 1     8676.313000
# 2     8634.710223
# 3     8880.697857
# 4     8945.327769
# 5     9125.620309
# 6     8938.769980
# 7     9159.802643
# 8     9393.495419
# 9     8467.504110
# 10    8738.398252
# 11    8864.145839
# 12    9502.111086
# 13    8977.937259
# 14    9199.133130
# 15    9462.161541
# 16    9125.089960
# 17    9571.429239
# 18    8920.680339
# 19    8398.336726
# 20    8509.744205
# Name: Purchase, dtype: float64

# %%
# Purchase By City Category Analysis
purchase_by_city=df.groupby('City_Category')['Purchase'].sum()
purchase_by_city
# Out:
# City_Category
# A    1247372909
# B    2009425550
# C    1571208486
# Name: Purchase, dtype: int64

# %%
# Purchase by Age Group
age_group_analysis=df.groupby('Age')['Purchase'].sum()
age_group_analysis
# Out:
# Age
# 0-17      128407061
# 18-25     871111483
# 26-35    1926713234
# 36-45     972308250
# 46-50     398732192
# 51-55     342967122
# 55+       187767603
# Name: Purchase, dtype: int64

# %%
# Drop Unnecessary colums
df.drop(['Product_ID'],axis=1)
# Out:
#         User_ID Gender    Age  Occupation City_Category  \
# 0       1000001      F   0-17          10             A
# 1       1000001      F   0-17          10             A
# 2       1000001      F   0-17          10             A
# 3       1000001      F   0-17          10             A
# 4       1000002      M    55+          16             C
# ...         ...    ...    ...         ...           ...
# 550063  1006033      M  51-55          13             B
# 550064  1006035      F  26-35           1             C
# 550065  1006036      F  26-35          15             B
# 550066  1006038      F    55+           1             C
# 550067  1006039      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# ...

# %%
# Converting Categorical Data into integer using map function
df['Gender']=df['Gender'].map({"M":1,"F":0})
df.head()
# Out:
# C:\Users\BHAR\AppData\Local\Temp\ipykernel_1052\697137045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=df['Gender'].map({"M":1,"F":0})
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# ...

# %%
df.rename(columns={
    "User_ID":"UserID",
    "Product_ID":"ProductID",
    "Gender":"IsMale",
    "Age":"AgeGroup",
    "Occupation":"OccupationID",
    "City_Category":"CityCategory",
    "Stay_In_Current_City_Years":"YearsInCity",
    "Marital_Status":"IsMarried",
    "Product_Category_1":"Category1",
    "Product_Category_2":"Category2",
    "Product_Category_3":"Category3",
    "Purchase":"PurchaseTotal"
},inplace=True)
df.head()
# Out:
# C:\Users\BHAR\AppData\Local\Temp\ipykernel_1052\2072524768.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
#     UserID  ProductID  IsMale AgeGroup  OccupationID CityCategory YearsInCity  \
# 0  1000001  P00069042       0     0-17            10            A           2
# 1  1000001  P00248942       0     0-17            10            A           2
# 2  1000001  P00087842       0     0-17            10            A           2
# 3  1000001  P00085442       0     0-17            10            A           2
# 4  1000002  P00285442       1      55+            16            C          4+
#
#    IsMarried  Category1  Category2  Category3  PurchaseTotal
# 0          0          3        0.0        0.0           8370
# 1          0          1        6.0       14.0          15200
# ...

# %%
# Age vs Purchase Barplot
plt.figure(figsize=(10,6))
sns.barplot(data=df,x='PurchaseTotal',y='AgeGroup')
plt.title('Age vs Purchase Total')
plt.show()

# %%
# Occupation Vs Purchased Items

plt.figure(figsize=(10,6))
sns.barplot(data=df,x='OccupationID',y='PurchaseTotal')
plt.title('Occupatoin Vs Purchased Producsts Barplot')
plt.ylabel('Purchase Total')
plt.xlabel('Occupation Id')
plt.show()

# %%
# Purchase items vs Category 1
plt.figure(figsize=(10,6))
sns.lineplot(data=df,x="Category1",y="PurchaseTotal",hue='IsMale')
plt.title("Purchase Total Vs Category1")
plt.xlabel("Category 1")
plt.ylabel("Purchase Total")
plt.show()

# %%
# Purchase Items vs Category 2
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Category2',y='PurchaseTotal',hue='IsMarried')
plt.title('Category 2 and Purchase Total Plot')
plt.ylabel("Purchase Items")
plt.show()

# %%
# Purchase Items vs Category 3
plt.figure(figsize=(10,6))
sns.jointplot(x='PurchaseTotal',y='Category3',data=df,kind='reg',
              truncate=False,xlim=(0,60),ylim=(0,12),color="m",height=7)
plt.xlabel('Purchased Total')
plt.show()

# %%
# City Category Pie Chart

plt.figure(figsize=(10,6))
df['CityCategory'].value_counts().plot(kind='pie',autopct='%1.1f%%',colors=['lightblue','lightgreen','lightcoral'])
plt.title('City Category Distribution')
plt.ylabel('')
plt.xlabel('City Category')
plt.show()
